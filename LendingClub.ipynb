# %% [markdown]
# I. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# II. Data Sourcing

# %%
loan_df = pd.read_csv('loan.csv')
loan_df.describe()
# Out:
# /var/folders/6j/knf6rnl14n77hhy_y3sx47mw0000gn/T/ipykernel_96189/118855965.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_df = pd.read_csv('loan.csv')
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# ...

# %%
loan_df.head()

print(loan_df.columns)

print(loan_df.shape )

loan_df.nunique()
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)
# (39717, 111)
# id                                39717
# member_id                         39717
# loan_amnt                           885
# funded_amnt                        1041
# funded_amnt_inv                    8205
# term                                  2
# int_rate                            371
# installment                       15383
# grade                                 7
# sub_grade                            35
# emp_title                         28820
# emp_length                           11
# home_ownership                        5
# ...

# %% [markdown]
# III. Data Cleaning and Manipulation

# %%
# Drop all the columns with all missing values

loan_data = data.dropna(axis=1, how='all')
loan_data.shape
# Out:
# (39717, 57)

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# Showing the loan data types

# %%
loan_data.dtypes
# Out:
# id                              int64
# member_id                       int64
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                        object
# loan_status                    object
# pymnt_plan                     object
# url                            object
# desc                           object
# purpose                        object
# title                          object
# zip_code                       object
# addr_state                     object
# dti                           float64
# ...

# %% [markdown]
# Loan Status Value counts

# %%
loan_data["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: count, dtype: int64

# %% [markdown]
# Loan Status as Pie chart

# %%
loan_data["loan_status"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Loan Status")
plt.show()

# %% [markdown]
# Loan status as Bar chart (Insights: Approx 90% of the applicants are fully paid))

# %%
loan_data["loan_status"].value_counts().plot(kind='bar')
plt.title("Loan Status")
plt.xlabel("Loan Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
#  Grade count as Bar chart

# %%
loan_data["grade"].value_counts().plot(kind='bar')
plt.title("Loan Grade")
plt.xlabel("Grade")
plt.ylabel("Count")
plt.show()

# %% [markdown]
#  Grade count as Pie chart

# %%
loan_data["grade"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Loan Grade")
plt.show()

# %% [markdown]
# Sub Grade's Count as Bar Chart

# %%
loan_data["sub_grade"].value_counts().plot(kind='bar')
plt.title("Loan Sub Grade")
plt.xlabel("Sub Grade")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Loan Purpose's count as Bar Chart (Insights: Approx 60% of the applicants applied loan for paying their other loans(Debt Consolidation))

# %%
loan_data["purpose"].value_counts().plot(kind='bar')
plt.title("Loan Purpose")
plt.xlabel("Purpose")
plt.ylabel("Count")
plt.show()
# Out:
# <Axes: xlabel='purpose'>

# %% [markdown]
# Verification Status's Count as Bar Chart

# %%
loan_data["verification_status"].value_counts().plot(kind='bar')
plt.title("Verification Status")
plt.xlabel("Verification Status")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Home Ownership's Count as Bar Chart

# %%
loan_data["home_ownership"].value_counts().plot(kind='bar')
plt.title("Home Ownership")
plt.xlabel("Home Ownership")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Loan Amount  distribution as Bar Chart

# %%
sns.displot(loan_data["loan_amnt"], kde=True)
plt.title("Loan Amount")
plt.show()

# %% [markdown]
# Loan amount distribution as box plot and it showing the mean is between 5000 and 15000

# %%
sns.boxenplot(loan_data["loan_amnt"])
plt.title("Loan Amount")
plt.show()

# %% [markdown]
# Loan Term Distribution shows that the most of loan term as 36

# %%
loan_data["term"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Loan Term")
plt.show()

# %% [markdown]
# Bivariant Analysis

# %% [markdown]
# The Bar Chart for Loan Amount by Term shows that the amount more than 10000 termed as 60 months

# %%
sns.barplot(x="term", y="loan_amnt", data=loan_data)
plt.title("Loan Amount by Term")
plt.xlabel("Term")
plt.ylabel("Loan Amount")
plt.show()

# %%
sns.barplot(x="loan_status", y="loan_amnt", data=loan_data)
plt.title("Loan Amount by Status")
plt.xlabel("Loan Status")
plt.ylabel("Loan Amount")
plt.show()

# %%
sns.boxplot(y="loan_amnt", x="loan_status", data=loan_data)
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>

# %% [markdown]
# Scatter Plot: Relationship between loan amount and interest rate
# Insites: If the higher interest rates and higher amount there are more charged offs

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='loan_amnt', y='int_rate', hue='loan_status', data=loan_data)
plt.title('Scatter Plot: Loan Amount vs Interest Rate by Loan Status')
plt.xlabel('Loan Amount')
plt.ylabel('Interest Rate')
plt.legend(title='Loan Status')
plt.show()

# %% [markdown]
# Box Plot: Distribution of interest rates across different grades

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='sub_grade', y='int_rate', hue='loan_status', data=loan_data)
plt.title('Box Plot: Interest Rate by Grade and Loan Status')
plt.xlabel('Grade')
plt.ylabel('Interest Rate')
plt.legend(title='Loan Status')
plt.show()

# %%
# Box Plot: Distribution of interest rates across different grades
plt.figure(figsize=(10, 6))
sns.boxplot(x='grade', y='int_rate', hue='loan_status', data=loan_data)
plt.title('Box Plot: Interest Rate by Grade and Loan Status')
plt.xlabel('Grade')
plt.ylabel('Interest Rate')
plt.legend(title='Loan Status')
plt.show()

# %% [markdown]
# Bar Plot: Count of loan statuses by grade

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='grade', hue='loan_status', data=loan_data)
plt.title('Bar Plot: Loan Status by Grade')
plt.xlabel('Grade')
plt.ylabel('Count')
plt.legend(title='Loan Status')
plt.show()

# %% [markdown]
# Bar Plot: Count of loan statuses by sub grade

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='sub_grade', hue='loan_status', data=loan_data)
plt.title('Bar Plot: Loan Status by Sub Grade')
plt.xlabel('Sub Grade')
plt.ylabel('Count')
plt.legend(title='Loan Status')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='loan_status', hue='verification_status', data=data1)
plt.title('Bar Plot: Verification Status by Grade')
plt.xlabel('Grade')
plt.ylabel('Count')
plt.legend(title='Verification Status')
plt.show()

# %% [markdown]
# Univariate Analysis: Annual Income

# %%
# Univariate Analysis: Annual Income
plt.figure(figsize=(10, 6))
sns.histplot(data1['annual_inc'], kde=True, log_scale=True)
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# HeatMap: All continuos variables
#
# Insights: It is clear from the Heatmap that how 'loan_amnt','funded_amnt' & 'funded_amnt_inv' are closely interrelated.
# So we can take any one column out of them for our analysis.

# %%
loan_data['loan_income_ratio']= loan_data['loan_amnt']/loan_data['annual_inc']
selected_columns = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'installment', 'int_rate', 'loan_income_ratio', 'annual_inc', 'dti']

if loan_data['int_rate'].dtype == 'object' and loan_data['int_rate'].str.contains('%').any():
    loan_data['int_rate'] = loan_data['int_rate'].str.replace('%', '').astype(float)

loan_data[selected_columns]
corr_matrix = loan_data[selected_columns].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True)
plt.title('Heatmap: Correlation Matrix')
plt.show()
# Out:
# /var/folders/6j/knf6rnl14n77hhy_y3sx47mw0000gn/T/ipykernel_96189/3006067613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_data['loan_income_ratio']= loan_data['loan_amnt']/loan_data['annual_inc']

# %% [markdown]
# Employment Length of Charged Off Loan Status
#
# Applicants less than 1 year of experience or more than 10 years experience probable of charged off

# %%
emp_len_loan_status = loan_data[['emp_length', 'loan_status']]
emp_len_loan_status  = emp_len_loan_status.loc[emp_len_loan_status['loan_status'].isin(['Charged Off'])]
emp_len_loan_status['emp_length'].value_counts().plot(kind='bar')
plt.title("Employment Length of Charged Off Loan Status")
plt.xlabel("Employment Length")
plt.ylabel("Count")
plt.show()
